# %%
# Import necessary libraries 
import pandas as pd
import sqlite3
import sqlalchemy as sqla

# %%
#Reading in csv created from milestone 2
Milestone2 = pd.read_csv("Milestone2_df.csv", sep=",", header=None, engine='python', encoding="utf-8-sig") # imports the dataset
Milestone2
# Out:
#          0                1                    2                    3   \
# 0     index             name            real_name            full_name
# 1         1          3-D Man  Delroy Garrett, Jr.  Delroy Garrett, Jr.
# 2         2    514A (Gotham)          Bruce Wayne                  NaN
# 3         3     A.I.M. Agent                  NaN                  NaN
# 4         4  A.M.A.Z.O. (CW)                  NaN                  NaN
# ...     ...              ...                  ...                  ...
# 1373   1479             Zane                 Zane                 Zane
# 1374   1480          Zatanna       Zatanna Zatara       Zatanna Zatara
# 1375   1483             Zoom       Hunter Zolomon       Hunter Zolomon
# 1376   1484    Zoom (New 52)       Hunter Zolomon                  NaN
# 1377   1485            Zzzax                  NaN                  NaN
#
#                  4                                                  5   \
# ...

# %%
#Reading in csv created from milestone 4
Milestone4 = pd.read_csv("milestone4.csv", sep=",", header=None, engine='python', encoding="utf-8-sig") # imports the dataset
Milestone4
# Out:
#         0    1                2                    3             4         5   \
# 0    index   id             name                 slug  intelligence  strength
# 1        0    1           A-Bomb             1-a-bomb            38       100
# 2        1    2       Abe Sapien         2-abe-sapien            88        28
# 3        2    3         Abin Sur           3-abin-sur            50        90
# 4        3    4      Abomination        4-abomination            63        80
# ..     ...  ...              ...                  ...           ...       ...
# 559    558  727  Yellowjacket II  727-yellowjacket-ii            50        10
# 560    559  728             Ymir             728-ymir            50       100
# 561    560  729             Yoda             729-yoda            88        52
# 562    561  730          Zatanna          730-zatanna            81        10
# 563    562  731             Zoom             731-zoom            50        10
#
# ...

# %%
#Reading in csv created from milestone 3, 1 of 2
Milestone3a = pd.read_csv("Milestone3_df2.csv", sep=",", header=None, engine='python', encoding="utf-8-sig") # imports the dataset
Milestone3a
# Out:
#         0     1                                    2                       3  \
# 0   index  Rank                                 Film  Gross[64] ($ millions)
# 1       1     1                    Avengers: Endgame              $1,223.60
# 2       2     2               Avengers: Infinity War                $640.50
# 3       3     3                       Captain Marvel                $456.70
# 4       4     4   Batman v Superman: Dawn of Justice                $422.50
# 5       5     5                         The Avengers                $392.50
# 6       6     6              Avengers: Age of Ultron                $392.40
# 7       7     7                         Spider-Man 3                $381.70
# 8       8     8           Captain America: Civil War                $379.50
# 9       9     9                           Iron Man 3                $372.50
# 10     10    10                        Black Panther                $371.40
# ...

# %%
#Reading in csv created from milestone 3, 2 of 2
Milestone3b = pd.read_csv("Milestone3_df3.csv", sep=",", header=None, engine='python', encoding="utf-8-sig") # imports the dataset
Milestone3b
# Out:
#         0     1                                    2                3     4  \
# 0   index  Rank                                 Film  Worldwide gross  Year
# 1       1     1                    Avengers: Endgame  $2,797,800,564   2019
# 2       2     2               Avengers: Infinity War  $2,048,359,754   2018
# 3       3     3                         The Avengers  $1,518,812,988   2012
# 4       4     4              Avengers: Age of Ultron  $1,405,403,694   2015
# 5       5     5                        Black Panther  $1,346,913,171   2018
# 6       6     6                        Incredibles 2  $1,242,805,359   2018
# 7       7     7                           Iron Man 3  $1,214,811,252   2013
# 8       8     8           Captain America: Civil War  $1,153,304,495   2016
# 9       9     9                              Aquaman  $1,148,161,807   2018
# 10     10    10            Spider-Man: Far From Home  $1,131,927,996   2019
# ...

# %%
#Merging my first two dataframes. Using combine first so df_covid1 is my source of truth
merge = Milestone2.combine_first(Milestone4)
merge
# Out:
#          0                1                    2                    3   \
# 0     index             name            real_name            full_name
# 1         1          3-D Man  Delroy Garrett, Jr.  Delroy Garrett, Jr.
# 2         2    514A (Gotham)          Bruce Wayne         2-abe-sapien
# 3         3     A.I.M. Agent             Abin Sur           3-abin-sur
# 4         4  A.M.A.Z.O. (CW)          Abomination        4-abomination
# ...     ...              ...                  ...                  ...
# 1373   1479             Zane                 Zane                 Zane
# 1374   1480          Zatanna       Zatanna Zatara       Zatanna Zatara
# 1375   1483             Zoom       Hunter Zolomon       Hunter Zolomon
# 1376   1484    Zoom (New 52)       Hunter Zolomon                  NaN
# 1377   1485            Zzzax                  NaN                  NaN
#
#                  4                                                  5   \
# ...

# %%
#Merging my third dataframe with the others and creating df_total
df_total = merge.combine_first(Milestone3a)
df_total
# Out:
#          0                1                    2                    3   \
# 0     index             name            real_name            full_name
# 1         1          3-D Man  Delroy Garrett, Jr.  Delroy Garrett, Jr.
# 2         2    514A (Gotham)          Bruce Wayne         2-abe-sapien
# 3         3     A.I.M. Agent             Abin Sur           3-abin-sur
# 4         4  A.M.A.Z.O. (CW)          Abomination        4-abomination
# ...     ...              ...                  ...                  ...
# 1373   1479             Zane                 Zane                 Zane
# 1374   1480          Zatanna       Zatanna Zatara       Zatanna Zatara
# 1375   1483             Zoom       Hunter Zolomon       Hunter Zolomon
# 1376   1484    Zoom (New 52)       Hunter Zolomon                  NaN
# 1377   1485            Zzzax                  NaN                  NaN
#
#                  4                                                  5   \
# ...

# %%
conn = sqlite3.connect("Superhero.db")

# %%
df_total.tosql('table', connection, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-d434df1744dc> in <module>
# ----> 1 df_total.tosql('table', connection, if_exists='replace', index=False)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tosql'

# %%
cur=conn.cursor()

# %%
cur.execute('SELECT * from df_total')

# %%
for row in cur.execute('SELECT * FROM df_total'):
    print(row)

# %%
#Created a dataframe out of my sqlite table
Superhero_db = pd.read_sql_query("SELECT * FROM df_total", conn)
Superhero_db
